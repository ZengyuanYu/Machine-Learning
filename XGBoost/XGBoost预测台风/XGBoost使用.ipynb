# %%
import pandas as pd
### load_data
titanic = pd.read_csv('http://biostat.mc.vanderbilt.edu/wiki/pub/Main/DataSets/titanic.txt')
X = titanic[['pclass', 'age', 'sex']]     # 输入空间
y = titanic['survived']                   # 输出空间
X.age.fillna(X.age.mean(), inplace=True)  # 填充缺失值（均值），inplace=True(无返回值，原地替换）
### split_data
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=33)
 
### feature_extraction
from sklearn.feature_extraction import DictVectorizer
vec = DictVectorizer(sparse=False)
X_train = vec.fit_transform(X_train.to_dict(orient='record'))
X_test = vec.transform(X_test.to_dict(orient='record'))

### create_model
# rfc
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)

# xgbc
from xgboost import XGBClassifier
xgbc = XGBClassifier()
xgbc.fit(X_train, y_train)

### model_score
print ('rfc.score=',rfc.score(X_test, y_test))
print('xgbc.score=',xgbc.score(X_test, y_test))
# Out:
# /home/yu/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:4355: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# rfc.score= 0.7872340425531915
# xgbc.score= 0.7872340425531915
# /home/yu/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# ...

# %% [markdown]
# 读取X和y,然后对X进行最大最小标准化

# %%
import pandas as pd

#读取数据
X = pd.read_csv('X_noyear_notitle.csv')
y = pd.read_csv('Y_noyear_notitle.csv')
pre = pd.read_csv('predicion.csv')
#标准化
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()

#分割验证集和测试集
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                test_size=0.25,
                                                random_state=33)
#特征提取
#from sklearn.feature_extraction import DictVectorizer
# vec = DictVectorizer(sparse=False)
# X_train = vec.fit_transform(X_train.to_dict(orient='record'))
# X_test = vec.transform(X_test.to_dict(orient='record'))
#标准化
X_train_Nor = min_max_scaler.fit_transform(X_train)
X_test_Nor = min_max_scaler.fit_transform(X_test)

#创建模型
from xgboost import XGBClassifier
xgbc = XGBClassifier(learning_rate=0.1)
xgbc.fit(X_train_Nor, y_train)

#模型预测
print(xgbc.score(X_test_Nor, y_test))
#print(xgbc.predict(X_test_Nor[0]))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-ac1ce24c632e> in <module>()
#       2
#       3 #读取数据
# ----> 4 X = pd.read_csv('X_noyear_notitle.csv')
#       5 y = pd.read_csv('Y_noyear_notitle.csv')
#       6 pre = pd.read_csv('predicion.csv')
#
# ...

# %%
import numpy as np
a = np.zeros((3,))
print(a)
b = np.argsort(a)[1]
print(b)
# Out:
# [0. 0. 0.]
# 1

# %% [markdown]
# 读取训练文件的某些特征相关列

# %%
import pandas as pd
data = pd.read_csv('X_50.csv',usecols=[140,139,138,137,136,134,133,132,131,153,
154, 144, 164, 162, 156, 159, 165, 163, 158, 157, 155, 451, 233, 222, 178,   8, 354, 208,
160, 461, 218, 161,  28, 359,  67, 267, 276,  64, 493, 304,  62,  43, 378, 483, 368, 425,
344,  58,  20, 422,  48, 437, 113,  66, 449,  32, 322, 442,   4, 334, 235, 171, 173, 412,
129,  45, 250, 435, 215,  31, 440, 254, 471, 462, 314, 476,  89, 119, 455, 116, 135,  27,
95, 497, 260,  50, 456,  97, 448, 115,   0, 441,  38, 329,])
print(data.shape)
data1 = pd.DataFrame(data)
data1.to_csv('X_50_feature.csv', index=None)
# Out:
# (50, 94)

# %% [markdown]
# 读取测试文件的某些特征相关列

# %%
import pandas as pd
data = pd.read_csv('X_16.csv',usecols=[140,139,138,137,136,134,133,132,131,153,
154, 144, 164, 162, 156, 159, 165, 163, 158, 157, 155, 451, 233, 222, 178,   8, 354, 208,
160, 461, 218, 161,  28, 359,  67, 267, 276,  64, 493, 304,  62,  43, 378, 483, 368, 425,
344,  58,  20, 422,  48, 437, 113,  66, 449,  32, 322, 442,   4, 334, 235, 171, 173, 412,
129,  45, 250, 435, 215,  31, 440, 254, 471, 462, 314, 476,  89, 119, 455, 116, 135,  27,
95, 497, 260,  50, 456,  97, 448, 115,   0, 441,  38, 329,])
print(data)
data1 = pd.DataFrame(data)
data1.to_csv('X_16_feature.csv', index=None)
# Out:
#            key0         key4         key8        key20        key27  \
# 0   5833.635905  5851.058594  5850.474284  5799.333984  5772.557454
# 1   5777.251139  5813.648763  5814.559733  5727.216471  5680.280924
# 2   5769.340332  5797.914388  5800.694661  5750.259277  5716.828451
# 3   5777.949707  5810.491374  5814.360189  5726.634440  5684.055664
# 4   5747.562826  5786.612142  5790.256999  5710.194661  5663.941081
# 5   5779.874674  5803.355306  5803.217285  5733.694173  5691.583822
# 6   5819.828288  5846.016276  5845.685384  5775.410645  5732.031087
# 7   5755.441895  5788.690267  5789.989258  5733.415039  5684.810384
# 8   5766.174642  5803.623698  5809.262044  5724.977051  5698.002767
# 9   5800.637858  5831.367839  5836.745117  5771.405273  5740.684408
# 10  5746.436035  5783.254883  5784.953288  5721.003092  5674.555339
# 11  5754.548828  5781.502279  5779.592122  5728.366211  5680.759115
# 12  5775.603353  5804.012695  5805.052246  5731.332682  5696.256999
# ...

# %% [markdown]
# X_50和X_16合并

# %%
import pandas as pd
data = pd.read_csv('X_16_feature.csv')
print(data)
unname = data.drop(['Unnamed: 0'], axis=1, inplace=True)
print(data)
# Out:
#            key0         key4         key8        key20        key27  \
# 0   5833.635905  5851.058594  5850.474284  5799.333984  5772.557454
# 1   5777.251139  5813.648763  5814.559733  5727.216471  5680.280924
# 2   5769.340332  5797.914388  5800.694661  5750.259277  5716.828451
# 3   5777.949707  5810.491374  5814.360189  5726.634440  5684.055664
# 4   5747.562826  5786.612142  5790.256999  5710.194661  5663.941081
# 5   5779.874674  5803.355306  5803.217285  5733.694173  5691.583822
# 6   5819.828288  5846.016276  5845.685384  5775.410645  5732.031087
# 7   5755.441895  5788.690267  5789.989258  5733.415039  5684.810384
# 8   5766.174642  5803.623698  5809.262044  5724.977051  5698.002767
# 9   5800.637858  5831.367839  5836.745117  5771.405273  5740.684408
# 10  5746.436035  5783.254883  5784.953288  5721.003092  5674.555339
# 11  5754.548828  5781.502279  5779.592122  5728.366211  5680.759115
# 12  5775.603353  5804.012695  5805.052246  5731.332682  5696.256999
# ...

# %%
import pandas as pd
import numpy as np

df1 = pd.read_csv('X_50_feature.csv')

df2 = pd.read_csv('X_16_feature.csv')
data = pd.concat([df1,df2],axis=0)
print(data)
data.to_csv("X_66_feature.csv")
# Out:
#            key0         key4         key8        key20        key27  \
# 0   5747.490723  5772.107096  5772.218424  5717.202311  5673.939290
# 1   5751.623698  5774.849447  5773.334147  5724.502116  5681.915039
# 2   5747.204915  5783.363607  5783.633138  5695.359049  5644.515462
# 3   5748.324707  5777.569987  5775.918620  5713.414714  5665.719727
# 4   5766.076009  5790.334147  5789.674805  5735.157064  5699.628255
# 5   5743.112467  5765.120605  5763.197591  5709.321126  5664.248047
# 6   5759.108724  5779.390462  5776.164714  5715.100911  5683.685384
# 7   5768.046387  5796.701009  5794.680664  5735.503418  5693.132324
# 8   5748.424154  5780.181641  5783.162272  5729.894694  5691.931315
# 9   5781.542806  5806.638997  5808.271322  5745.067057  5710.881999
# 10  5726.950195  5766.291016  5772.050456  5700.382161  5660.981934
# 11  5774.936198  5801.173177  5799.378743  5718.031087  5678.118164
# 12  5761.850911  5790.345540  5789.744629  5719.068359  5671.637695
# ...

# %%
import pandas as pd
import numpy as np

df1 = pd.read_csv('Y_50.csv')

df2 = pd.read_csv('Y_16.csv')
data = pd.concat([df1,df2],axis=0)
print(data)
data.to_csv("Y_66_feature.csv")
# Out:
#     times
# 0     6.0
# 1     8.0
# 2     7.0
# 3     7.0
# 4     4.0
# 5     4.0
# 6     5.0
# 7     6.0
# 8     4.0
# 9     6.0
# 10    7.0
# 11    4.0
# 12    5.0
# 13    6.0
# 14    7.0
# 15    3.0
# 16    8.0
# 17    4.0
# 18    1.0
# 19    6.0
# 20    5.0
# 21    5.0
# 22    7.0
# 23    9.0
# 24    6.0
# 25    5.0
# 26    2.0
# 27    5.0
# 28    4.0
# 29    9.0
# ..    ...
# 36    2.0
# 37    5.0
# 38    4.0
# 39    5.0
# 40    5.0
# 41    5.0
# 42    7.0
# 43    5.0
# 44    7.0
# 45    3.0
# 46    2.0
# 47    4.0
# 48    7.0
# 49    5.0
# 0     5.0
# 1     3.0
# 2     4.0
# 3     6.0
# 4     5.0
# 5     4.0
# 6     4.0
# 7     7.0
# 8     6.0
# 9     4.0
# 10    7.0
# 11    4.0
# 12    4.0
# 13    5.0
# 14    4.0
# 15    5.0
#
# [66 rows x 1 columns]
